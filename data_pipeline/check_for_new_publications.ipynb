# %%
'''
2) Check Open Alex, Crossref, (Arxiv) for pdfs
3) if unique add to pdf storage and add name to title column 
'''
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %%
import pathlib
from utils import topic_model_config

email = topic_model_config.EMAIL
db_path = pathlib.Path(topic_model_config.DATABASE_PATH)
all_pdf_path = pathlib.Path(topic_model_config.ALL_PDF_FOLDER_PATH)
selected_model_name = topic_model_config.MODEL

# %%
from database.database_manager import DatabaseManager
from publication_API.crossref_api import CrossrefAPI
from publication_API.arxiv_api import ArxivAPI
from publication_API.open_alex import OpenAlex



database_manager = DatabaseManager(db_path)
crossref_api = CrossrefAPI(email=email, rows=10, database_manager=database_manager)
open_alex_api = OpenAlex(database_manager=database_manager)
# arxiv_api = ArxivAPI(rows=10, database_manager=database_manager)

author_list = database_manager.get_all_authors()

# %%
#Pull all publications
for author_id in author_list:
    crossref_api.api_call(author_id)
    open_alex_api.api_call(author_id)
    # arxiv_api.api_call(author_id)
# Out:
# 2024-11-15 19:23:11,329 - INFO - Searching for publications using crossref started...
# 2024-11-15 19:23:14,247 - INFO - No URL - skipping publication The Early Impact of the Affordable Care Act State-By-State
# 2024-11-15 19:23:19,795 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf, skipping download.
# 2024-11-15 19:23:19,796 - INFO - No URL - skipping publication Censored Quantile Instrumental Variable Estimates of the Price Elasticity of Expenditure on Medical Care
# 2024-11-15 19:23:19,796 - INFO - No URL - skipping publication What Do Longitudinal Data on Millions of Hospital Visits Tell us About The Value of Public Health Insurance as a Safety Net for the Young and Privately Insured?
# 2024-11-15 19:23:19,796 - INFO - No URL - skipping publication Estimating the Tradeoff Between Risk Protection and Moral Hazard with a Nonlinear Budget Set Model of Health Insurance
# 2024-11-15 19:23:19,797 - INFO - No URL - skipping publication A model of a randomized experiment with an application to the PROWESS clinical trial
# 2024-11-15 19:23:19,797 - INFO - No URL - skipping publication Behavior within a Clinical Trial and Implications for Mammography Guidelines
# 2024-11-15 19:23:19,797 - INFO - No URL - skipping publication Reconciling Seemingly Contradictory Results from the Oregon Health Insurance Experiment and the Massachusetts Health Reform
# 2024-11-15 19:23:19,797 - INFO - No URL - skipping publication Mammograms and Mortality: How Has the Evidence Evolved?
# 2024-11-15 19:23:19,797 - INFO - No URL - skipping publication A Model of a Randomized Experiment with an Application to the PROWESS Clinical Trial
# 2024-11-15 19:23:19,804 - INFO - Searching for publications using Open Alex started...
# 2024-11-15 19:23:20,375 - INFO - Open Access publications for Amanda Kowalski (Page 1):
# 2024-11-15 19:23:22,033 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/pmc3501746?pdf=render.pdf, skipping download.
# 2024-11-15 19:23:24,748 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/aer.20130758.pdf, skipping download.
# 2024-11-15 19:23:26,062 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/pmc2903901?pdf=render.pdf, skipping download.
# 2024-11-15 19:23:27,529 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/662526252.pdf, skipping download.
# 2024-11-15 19:23:27,673 - INFO - HEAD request could not confirm PDF content at https://academic.oup.com/restud/article-pdf/87/2/792/32780043/rdz039.pdf, attempting GET.
# 2024-11-15 19:23:27,800 - WARNING - Failed to download PDF, status code: 403
# 2024-11-15 19:23:29,175 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w15085.pdf, skipping download.
# 2024-11-15 19:23:30,652 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/pmc4837080?pdf=render.pdf, skipping download.
# 2024-11-15 19:23:31,580 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/818856467.pdf, skipping download.
# 2024-11-15 19:23:33,451 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w22363.pdf, skipping download.
# 2024-11-15 19:23:34,504 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w17748.pdf, skipping download.
# 2024-11-15 19:23:36,408 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w18108.pdf, skipping download.
# 2024-11-15 19:23:38,501 - INFO - HEAD request could not confirm PDF content at https://repository.upenn.edu/bitstreams/0e0c4f0a-4074-4faa-92d8-40f0da2ed8a2/download, attempting GET.
# 2024-11-15 19:23:39,567 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/download.pdf, skipping download.
# 2024-11-15 19:23:39,826 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/Fall2014BPEA_Kowalski.pdf, skipping download.
# 2024-11-15 19:23:40,989 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/IR_CISOPTR_204.pdf, skipping download.
# 2024-11-15 19:23:42,661 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w15085.pdf, skipping download.
# 2024-11-15 19:23:43,451 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/20130756_app.pdf, skipping download.
# 2024-11-15 19:23:45,191 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/w24647.pdf, skipping download.
# 2024-11-15 19:23:46,151 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/viewcontent.cgi?article=1236&context=up_workingpapers.pdf, skipping download.
# 2024-11-15 19:23:49,297 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/jep.35.2.119.pdf, skipping download.
# 2024-11-15 19:23:49,445 - INFO - PDF already exists at /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/Fall2014BPEA_Kowalski.pdf, skipping download.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 for author_id in author_list:
#       3     crossref_api.api_call(author_id)
# ----> 4     open_alex_api.api_call(author_id)
#
# File ~/expert_field_project/data_pipeline/publication_API/open_alex.py:76, in OpenAlex.api_call(self, author_id)
#      69             publication = {
#      70                 'doi': doi_number,
#      71                 'title': work['title'],
#      72                 'author_id': author_id,
#      73                 'url': pdf_url
#      74             }
#      75             if publication['url']:
# ---> 76                 if self.download_pdf(publication['url'], publication['author_id']):
#      77                     self.check_for_duplicates(author_name, publication)
#      78 else:
#
# File /nfs/turbo/si-acastel/expert_field_project/data_pipeline/publication_API/base_api.py:38, in BaseAPI.download_pdf(self, url, author_id)
#      35 os.makedirs(save_directory, exist_ok=True)
#      36 try:
#      37     # Perform HEAD request to verify the URL points to a PDF
# ---> 38     response = requests.head(url, allow_redirects=True, timeout=10)
#      39     if 'application/pdf' not in response.headers.get('Content-Type', '').lower():
#      40         logging.info(f'HEAD request could not confirm PDF content at {url}, attempting GET.')
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/api.py:100, in head(url, **kwargs)
#      89 r"""Sends a HEAD request.
#      90
#      91 :param url: URL for the new :class:`Request` object.
#    (...)
#      96 :rtype: requests.Response
#      97 """
#      99 kwargs.setdefault("allow_redirects", False)
# --> 100 return request("head", url, **kwargs)
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/.conda/envs/test_env/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/.conda/envs/test_env/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/.conda/envs/test_env/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/.conda/envs/test_env/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/.conda/envs/test_env/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.conda/envs/test_env/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from NLP.data_processor import TopicModelDataPreprocessor
from NLP.hdp import HDPTopicModel
# from NLP.bert import BERTTopicModel
# from NLP.fastopic import FASTopicModel
from NLP.lda import LDATopicModel
from NLP.zeroshot import ZeroShotClassifier
# from NLP.guidedlda import GuidedLDATopicModel

topic_model_processor = TopicModelDataPreprocessor()

match selected_model_name:
    case "hdp":
        for author_folder in all_pdf_path.iterdir():
            if author_folder.is_dir():
                docs = topic_model_processor.get_and_process_pdf_files(author_folder=author_folder)
                model_obj = HDPTopicModel()
                model_obj.train(docs)
                topics = model_obj.get_topics()
                topics = model_obj.log_topics(topics)
    # case "bert":
    #     model = BERTTopicModel()
    #     def get_topics(model, docs):
    #         model.train_embeddings(docs)
    #         return model.extract_topics(n=10)
    # case "fastopic":
    #     model = FASTopicModel()
    #     def get_topics(model, docs):
    #         model.fit(docs)
    #         return model.retrieve_topics(limit=10)
    case "lda":
        for author_folder in all_pdf_path.iterdir():
            if author_folder.is_dir():
                docs = topic_model_processor.get_and_process_pdf_files(author_folder=author_folder)
                model_obj = LDATopicModel()
                lda_model, corpus, dictionary = model_obj.train(docs)
                topics = model_obj.get_topics(lda_model=lda_model)
    case "zeroshot":
        for author_folder in all_pdf_path.iterdir():
            if author_folder.is_dir():
                docs = topic_model_processor.get_entire_author_text(author_folder=author_folder)
                model_obj = ZeroShotClassifier()
                results_df = model_obj.classify_with_confidence_threshold(docs)
                quality_analysis = model_obj.analyze_classification_quality(results_df)
                model_obj.log_topics(results_df, quality_analysis)
                
    # case "guidedlda":
    #     model = GuidedLDATopicModel()
    #     def get_topics(model, docs):
    #         model.initialize(docs)
    #         return model.topic_distribution(top_n=10)
    case _:
        raise ValueError(f"Unsupported topic model: {selected_model_name}")

# Process documents and retrieve topics
# Out:
# 2024-11-15 19:45:21,242 - INFO - Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-11-15 19:45:21,243 - INFO - NumExpr defaulting to 8 threads.
# [nltk_data] Downloading package stopwords to /home/hudah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-11-15 19:45:24,047 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/jdos/xml.pdf
# 2024-11-15 19:45:24,052 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/jdos/589297.pdf
# 2024-11-15 19:45:28,307 - INFO - collecting all words and their counts
# 2024-11-15 19:45:28,308 - INFO - PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-11-15 19:45:28,334 - INFO - collected 34494 token types (unigram + bigrams) from a corpus of 34635 words and 8 sentences
# 2024-11-15 19:45:28,334 - INFO - merged Phrases<34494 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:28,335 - INFO - Phrases lifecycle event {'msg': 'built Phrases<34494 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.03s', 'datetime': '2024-11-15T19:45:28.335339', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:28,335 - INFO - exporting phrases from Phrases<34494 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:28,365 - INFO - FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<727 phrases, min_count=2, threshold=10> from Phrases<34494 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.03s', 'datetime': '2024-11-15T19:45:28.365049', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# /home/hudah/expert_field_project/data_pipeline/NLP/hdp.py:40: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#
# /home/hudah/expert_field_project/data_pipeline/NLP/hdp.py:44: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   for key in topics:
# 2024-11-15 19:45:28,692 - INFO - Iteration: 0	Log-likelihood: -7.57473384507027	Num. of topics: 19
# 2024-11-15 19:45:28,993 - INFO - Iteration: 100	Log-likelihood: -7.500271724817226	Num. of topics: 25
# 2024-11-15 19:45:29,287 - INFO - Iteration: 200	Log-likelihood: -7.552313976293955	Num. of topics: 27
# 2024-11-15 19:45:29,639 - INFO - Iteration: 300	Log-likelihood: -7.467472277680011	Num. of topics: 30
# 2024-11-15 19:45:29,962 - INFO - Iteration: 400	Log-likelihood: -7.372876401024695	Num. of topics: 30
# 2024-11-15 19:45:30,250 - INFO - Iteration: 500	Log-likelihood: -7.390002850781667	Num. of topics: 32
# 2024-11-15 19:45:30,518 - INFO - Iteration: 600	Log-likelihood: -7.352390228889287	Num. of topics: 28
# 2024-11-15 19:45:30,805 - INFO - Iteration: 700	Log-likelihood: -7.398865879497084	Num. of topics: 30
# 2024-11-15 19:45:31,109 - INFO - Iteration: 800	Log-likelihood: -7.321312549457603	Num. of topics: 34
# 2024-11-15 19:45:31,434 - INFO - Iteration: 900	Log-likelihood: -7.161736056171296	Num. of topics: 32
# 2024-11-15 19:45:31,437 - INFO - [('docket', 0.06897122412919998), ('deal', 0.05241934955120087), ('license', 0.034161411225795746), ('technology', 0.020815016701817513), ('licensee', 0.016556894406676292), ('inventor', 0.016212066635489464), ('tlos', 0.015177568420767784), ('problem', 0.014832725748419762), ('meeting', 0.010739865712821484), ('professional', 0.01034992653876543)]
# 2024-11-15 19:45:31,437 - INFO - [('common', 0.021860197186470032), ('mean', 0.020794231444597244), ('response', 0.01660003513097763), ('hold', 0.016530316323041916), ('several', 0.015091640874743462), ('procedure', 0.013583245687186718), ('expert', 0.013332393951714039), ('people', 0.012829048559069633), ('help', 0.012829048559069633), ('chicago_press', 0.012799404561519623)]
# 2024-11-15 19:45:31,437 - INFO - [('skepticism', 0.036897923797369), ('scientist', 0.03550749644637108), ('postdoc', 0.033288776874542236), ('resistance', 0.028296660631895065), ('method', 0.02120009995996952), ('jill', 0.01997646689414978), ('criticism', 0.01997646689414978), ('position', 0.01956586167216301), ('group', 0.018437525257468224), ('multidisciplinary', 0.018312428146600723)]
# 2024-11-15 19:45:31,438 - INFO - [('rule', 0.026494700461626053), ('owensmith_powell', 0.024087661877274513), ('patent_volume', 0.02168063074350357), ('model', 0.02047719992697239), ('time_period', 0.019273603335022926), ('bayhdole', 0.019273603335022926), ('transfer', 0.01807013526558876), ('organizational', 0.017999524250626564), ('campus', 0.01715482957661152), ('adaptation', 0.016866572201251984)]
# 2024-11-15 19:45:31,444 - INFO - [('public_domain', 0.09433698654174805), ('concept', 0.040508538484573364), ('defend', 0.040508538484573364), ('court', 0.040508538484573364), ('law', 0.0388282909989357), ('conceptual', 0.038177501410245895), ('stock', 0.019157350063323975), ('basic', 0.019157350063323975), ('ing', 0.019157350063323975), ('domain', 0.019157350063323975)]
# 2024-11-15 19:45:31,444 - INFO - [('mcsherry', 0.08923265337944031), ('own', 0.07142243534326553), ('intellectual_property', 0.05241982266306877), ('book', 0.025785015895962715), ('artifact', 0.02535436302423477), ('harvard_university', 0.02535436302423477), ('tion', 0.02535436302423477), ('relationship_public', 0.02535436302423477), ('conception', 0.021076878532767296), ('professor', 0.017991796135902405)]
# 2024-11-15 19:45:31,444 - INFO - [('ownership', 0.05558876320719719), ('realm', 0.044502999633550644), ('conflict', 0.044502999633550644), ('legal', 0.0334172323346138), ('freedom', 0.031533483415842056), ('chapter', 0.031533483415842056), ('autonomy', 0.02271077409386635), ('academy', 0.02271077409386635), ('march', 0.022331465035676956), ('problematic', 0.01584670878946781)]
# 2024-11-15 19:45:31,453 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/minjoon/do.php?a=current&b=11&bidx=576&aidx=7125.pdf
# 2024-11-15 19:45:31,491 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/minjoon/fulltext.html.pdf
# 2024-11-15 19:45:31,551 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/minjoon/xml.pdf
# 2024-11-15 19:45:31,652 - INFO - collecting all words and their counts
# 2024-11-15 19:45:31,652 - INFO - PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-11-15 19:45:31,654 - INFO - collected 2172 token types (unigram + bigrams) from a corpus of 1824 words and 2 sentences
# 2024-11-15 19:45:31,654 - INFO - merged Phrases<2172 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:31,654 - INFO - Phrases lifecycle event {'msg': 'built Phrases<2172 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.00s', 'datetime': '2024-11-15T19:45:31.654522', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:31,654 - INFO - exporting phrases from Phrases<2172 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:31,656 - INFO - FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<63 phrases, min_count=2, threshold=10> from Phrases<2172 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.00s', 'datetime': '2024-11-15T19:45:31.656428', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:31,666 - INFO - Iteration: 0	Log-likelihood: -2.9021163042531954	Num. of topics: 3
# 2024-11-15 19:45:31,671 - INFO - Iteration: 100	Log-likelihood: -4.067282962903395	Num. of topics: 4
# 2024-11-15 19:45:31,676 - INFO - Iteration: 200	Log-likelihood: -4.192822279914845	Num. of topics: 6
# 2024-11-15 19:45:31,681 - INFO - Iteration: 300	Log-likelihood: -4.0116664555210875	Num. of topics: 4
# 2024-11-15 19:45:31,686 - INFO - Iteration: 400	Log-likelihood: -4.100411925762558	Num. of topics: 4
# 2024-11-15 19:45:31,690 - INFO - Iteration: 500	Log-likelihood: -2.684770793012321	Num. of topics: 3
# 2024-11-15 19:45:31,694 - INFO - Iteration: 600	Log-likelihood: -2.6242125890103587	Num. of topics: 3
# 2024-11-15 19:45:31,699 - INFO - Iteration: 700	Log-likelihood: -4.122950174453988	Num. of topics: 5
# 2024-11-15 19:45:31,704 - INFO - Iteration: 800	Log-likelihood: -4.061824511239565	Num. of topics: 3
# 2024-11-15 19:45:31,710 - INFO - Iteration: 900	Log-likelihood: -4.03660793039764	Num. of topics: 4
# 2024-11-15 19:45:31,710 - INFO - [('sport', 0.1056346520781517), ('art', 0.1056346520781517), ('questionnaire', 0.08805001527070999), ('participant', 0.08805001527070999), ('year', 0.06167306751012802), ('injury_location', 0.06167306751012802), ('study', 0.06167306751012802), ('type_injury', 0.06167306751012802), ('athlete', 0.052880749106407166), ('location_injury', 0.04408843070268631)]
# 2024-11-15 19:45:31,710 - INFO - [('intensity', 0.12998564541339874), ('foreground', 0.09458144754171371), ('skeleton_characteristic', 0.08278004825115204), ('september', 0.08278004825115204), ('realtime_human', 0.07097865641117096), ('use_image', 0.07097865641117096), ('object', 0.07097865641117096), ('model', 0.07097865641117096), ('color', 0.07097865641117096), ('intensity_block', 0.07097865641117096)]
# 2024-11-15 19:45:31,710 - INFO - [('texture', 0.1358150988817215), ('jbe_vol', 0.12225315719842911), ('skeleton', 0.12225315719842911), ('intensity_texture', 0.10869121551513672), ('face', 0.10869121551513672), ('object_segmentation', 0.09512926638126373), ('fig', 0.08156732469797134), ('region', 0.06800537556409836), ('minjoon_kim', 0.06800537556409836), ('video', 0.06800537556409836)]
# 2024-11-15 19:45:31,711 - INFO - [('data', 0.2645357549190521), ('frequent', 0.2645357549190521), ('injury_diagnosis', 0.2205522060394287), ('neck_head', 0.2205522060394287), ('competition', 0.0006345482543110847), ('athlete', 0.0006345482543110847), ('realtime_human', 0.0006345482543110847), ('use_image', 0.0006345482543110847), ('object', 0.0006345482543110847), ('model', 0.0006345482543110847)]
# 2024-11-15 19:45:32,245 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/revathy/xml.pdf
# 2024-11-15 19:45:35,139 - INFO - collecting all words and their counts
# 2024-11-15 19:45:35,140 - INFO - PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-11-15 19:45:35,182 - INFO - collected 43220 token types (unigram + bigrams) from a corpus of 55533 words and 10 sentences
# 2024-11-15 19:45:35,182 - INFO - merged Phrases<43220 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:35,183 - INFO - Phrases lifecycle event {'msg': 'built Phrases<43220 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.04s', 'datetime': '2024-11-15T19:45:35.182968', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:35,183 - INFO - exporting phrases from Phrases<43220 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:35,220 - INFO - FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<1718 phrases, min_count=2, threshold=10> from Phrases<43220 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.04s', 'datetime': '2024-11-15T19:45:35.220673', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:35,649 - INFO - Iteration: 0	Log-likelihood: -7.082118569820323	Num. of topics: 27
# 2024-11-15 19:45:36,064 - INFO - Iteration: 100	Log-likelihood: -7.113555603272295	Num. of topics: 28
# 2024-11-15 19:45:36,466 - INFO - Iteration: 200	Log-likelihood: -7.00781071312514	Num. of topics: 26
# 2024-11-15 19:45:36,863 - INFO - Iteration: 300	Log-likelihood: -6.8608202671107295	Num. of topics: 30
# 2024-11-15 19:45:37,278 - INFO - Iteration: 400	Log-likelihood: -7.0191357970466655	Num. of topics: 31
# 2024-11-15 19:45:37,701 - INFO - Iteration: 500	Log-likelihood: -7.003231116226146	Num. of topics: 32
# 2024-11-15 19:45:38,134 - INFO - Iteration: 600	Log-likelihood: -7.059896770817768	Num. of topics: 29
# 2024-11-15 19:45:38,585 - INFO - Iteration: 700	Log-likelihood: -7.020346773762135	Num. of topics: 34
# 2024-11-15 19:45:39,069 - INFO - Iteration: 800	Log-likelihood: -6.985939656858691	Num. of topics: 36
# 2024-11-15 19:45:39,538 - INFO - Iteration: 900	Log-likelihood: -7.002368076582665	Num. of topics: 31
# 2024-11-15 19:45:39,540 - INFO - [('emdin', 0.009873826056718826), ('ryan_deci', 0.009438219480216503), ('motivation', 0.009239212609827518), ('teach', 0.00911767315119505), ('educational_psychologist', 0.009053751826286316), ('experience', 0.008510062471032143), ('develop', 0.008183526806533337), ('achieve', 0.00779737951233983), ('king', 0.007387174759060144), ('demonstrate', 0.0073133050464093685)]
# 2024-11-15 19:45:39,541 - INFO - [('teacher_education', 0.05511128902435303), ('instructional_practice', 0.026419570669531822), ('multicultural_education', 0.025964146479964256), ('achievement_goal', 0.02232075296342373), ('culturally_diverse', 0.017575204372406006), ('classroom_practice', 0.01600375957787037), ('practice', 0.014896348118782043), ('midgley', 0.012756848707795143), ('discomfort_interact', 0.012004062533378601), ('discomfort', 0.011374778114259243)]
# 2024-11-15 19:45:39,541 - INFO - [('culture', 0.03439556807279587), ('cultural', 0.020061666145920753), ('education_doi', 0.013847059570252895), ('pedagogy', 0.013341465033590794), ('cultural_group', 0.011953107081353664), ('share', 0.011469612829387188), ('classroom', 0.011224974878132343), ('align', 0.01091694738715887), ('teaching', 0.010144022293388844), ('culturally', 0.009468186646699905)]
# 2024-11-15 19:45:39,547 - INFO - [('percent_student', 0.121136374771595), ('predominantly_white', 0.08623432368040085), ('elementary_middle', 0.043164171278476715), ('finding_suggest', 0.034049585461616516), ('prevalence', 0.034049585461616516), ('oftentimes', 0.034049585461616516), ('approximately', 0.03035460039973259), ('child_leave', 0.03035460039973259), ('school_administrator', 0.025936106219887733), ('check', 0.022731060162186623)]
# 2024-11-15 19:45:39,549 - INFO - [('tesseract_ocr', 0.18704523146152496), ('achieve', 0.07833600044250488), ('produce', 0.07453051209449768), ('extraction', 0.03753890469670296), ('like', 0.02332114428281784), ('open', 0.022665265947580338), ('position', 0.019705742597579956), ('specic', 0.019705742597579956), ('memory', 0.019705742597579956), ('september', 0.019705742597579956)]
# 2024-11-15 19:45:39,549 - INFO - [('couple', 0.13105161488056183), ('start', 0.044873546808958054), ('hill', 0.03932831436395645), ('scholarship', 0.03932831436395645), ('definitely', 0.037614606320858), ('perceived', 0.029969913884997368), ('elite', 0.026340443640947342), ('world', 0.025088658556342125), ('retain', 0.0197454821318388), ('grant', 0.0197454821318388)]
# 2024-11-15 19:45:39,550 - INFO - [('pdf', 0.05010624974966049), ('issn_print', 0.037560947239398956), ('identication', 0.037560947239398956), ('weave_cultural', 0.037560947239398956), ('perceived', 0.028659915551543236), ('whose', 0.028659915551543236), ('multicultural_education', 0.028659915551543236), ('interview', 0.02175573818385601), ('implicit', 0.02175573818385601), ('matter', 0.01611461490392685)]
# 2024-11-15 19:45:39,842 - INFO - collecting all words and their counts
# 2024-11-15 19:45:39,843 - INFO - PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-11-15 19:45:39,847 - INFO - collected 5848 token types (unigram + bigrams) from a corpus of 5319 words and 2 sentences
# 2024-11-15 19:45:39,847 - INFO - merged Phrases<5848 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:39,848 - INFO - Phrases lifecycle event {'msg': 'built Phrases<5848 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.01s', 'datetime': '2024-11-15T19:45:39.847991', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:39,848 - INFO - exporting phrases from Phrases<5848 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:39,852 - INFO - FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<111 phrases, min_count=2, threshold=10> from Phrases<5848 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.00s', 'datetime': '2024-11-15T19:45:39.852810', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:39,889 - INFO - Iteration: 0	Log-likelihood: -5.043517663864176	Num. of topics: 2
# 2024-11-15 19:45:39,916 - INFO - Iteration: 100	Log-likelihood: -5.009600816540149	Num. of topics: 2
# 2024-11-15 19:45:39,943 - INFO - Iteration: 200	Log-likelihood: -5.010004327349029	Num. of topics: 2
# 2024-11-15 19:45:39,969 - INFO - Iteration: 300	Log-likelihood: -5.041097876206988	Num. of topics: 2
# 2024-11-15 19:45:39,995 - INFO - Iteration: 400	Log-likelihood: -5.041664767544848	Num. of topics: 2
# 2024-11-15 19:45:40,022 - INFO - Iteration: 500	Log-likelihood: -5.041750222074262	Num. of topics: 2
# 2024-11-15 19:45:40,048 - INFO - Iteration: 600	Log-likelihood: -5.041870648912553	Num. of topics: 2
# 2024-11-15 19:45:40,075 - INFO - Iteration: 700	Log-likelihood: -5.0412549209834125	Num. of topics: 2
# 2024-11-15 19:45:40,101 - INFO - Iteration: 800	Log-likelihood: -5.064518007545725	Num. of topics: 3
# 2024-11-15 19:45:40,130 - INFO - Iteration: 900	Log-likelihood: -5.329458235808162	Num. of topics: 4
# 2024-11-15 19:45:40,131 - INFO - [('year', 0.04813598841428757), ('panel_study', 0.04126295819878578), ('change', 0.03954469785094261), ('survey', 0.03610818460583687), ('include', 0.03610818460583687), ('medicare', 0.030953411012887955), ('impact', 0.029235154390335083), ('sipp', 0.02408038079738617), ('economics', 0.022362124174833298), ('psid', 0.022362124174833298)]
# 2024-11-15 19:45:40,131 - INFO - [('cps', 0.10139140486717224), ('information', 0.08376916497945786), ('age', 0.07495804131031036), ('levy_new', 0.06614692509174347), ('panel', 0.05293024331331253), ('survey', 0.044119130820035934), ('include', 0.044119130820035934), ('yes_yes', 0.03971357271075249), ('available', 0.03530801460146904), ('focus', 0.03530801460146904)]
# 2024-11-15 19:45:40,132 - INFO - [('status', 0.10363039374351501), ('national', 0.10363039374351501), ('make', 0.10363039374351501), ('new_panel', 0.08063827455043793), ('add_health', 0.08063827455043793), ('nhis_nhanes', 0.06914221495389938), ('hospital', 0.06914221495389938), ('service_research', 0.05764615163207054), ('assess', 0.05764615163207054), ('area', 0.05764615163207054)]
# 2024-11-15 19:45:40,133 - INFO - [('penalty', 0.34865978360176086), ('worker', 0.30515575408935547), ('consumer', 0.21814770996570587), ('level', 0.0006276302738115191), ('link', 0.0006276302738115191), ('oregon', 0.0006276302738115191), ('economic', 0.0006276302738115191), ('risk', 0.0006276302738115191), ('note', 0.0006276302738115191), ('fact', 0.0006276302738115191)]
# 2024-11-15 19:45:41,109 - WARNING - couldn't open /nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/sungheel/xml.pdf
# 2024-11-15 19:45:46,460 - INFO - collecting all words and their counts
# 2024-11-15 19:45:46,461 - INFO - PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-11-15 19:45:46,527 - INFO - collected 67440 token types (unigram + bigrams) from a corpus of 83807 words and 26 sentences
# 2024-11-15 19:45:46,527 - INFO - merged Phrases<67440 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:46,527 - INFO - Phrases lifecycle event {'msg': 'built Phrases<67440 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.07s', 'datetime': '2024-11-15T19:45:46.527802', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:46,528 - INFO - exporting phrases from Phrases<67440 vocab, min_count=2, threshold=10, max_vocab_size=40000000>
# 2024-11-15 19:45:46,585 - INFO - FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<3506 phrases, min_count=2, threshold=10> from Phrases<67440 vocab, min_count=2, threshold=10, max_vocab_size=40000000> in 0.06s', 'datetime': '2024-11-15T19:45:46.585664', 'gensim': '4.3.3', 'python': '3.11.10 (main, Oct  3 2024, 07:29:13) [GCC 11.2.0]', 'platform': 'Linux-4.18.0-477.51.1.el8_8.x86_64-x86_64-with-glibc2.28', 'event': 'created'}
# 2024-11-15 19:45:47,015 - INFO - Iteration: 0	Log-likelihood: -6.807313632755601	Num. of topics: 30
# 2024-11-15 19:45:47,389 - INFO - Iteration: 100	Log-likelihood: -6.791308550732784	Num. of topics: 33
# 2024-11-15 19:45:47,807 - INFO - Iteration: 200	Log-likelihood: -6.738967105037668	Num. of topics: 42
# 2024-11-15 19:45:48,279 - INFO - Iteration: 300	Log-likelihood: -6.681967087563281	Num. of topics: 51
# 2024-11-15 19:45:48,737 - INFO - Iteration: 400	Log-likelihood: -6.679885964503476	Num. of topics: 57
# 2024-11-15 19:45:49,237 - INFO - Iteration: 500	Log-likelihood: -6.672062158451954	Num. of topics: 60
# 2024-11-15 19:45:49,770 - INFO - Iteration: 600	Log-likelihood: -6.68651770276081	Num. of topics: 59
# 2024-11-15 19:45:50,302 - INFO - Iteration: 700	Log-likelihood: -6.719385487313094	Num. of topics: 53
# 2024-11-15 19:45:50,840 - INFO - Iteration: 800	Log-likelihood: -6.671452661486715	Num. of topics: 53
# 2024-11-15 19:45:51,355 - INFO - Iteration: 900	Log-likelihood: -6.668226691587676	Num. of topics: 45
# 2024-11-15 19:45:51,359 - INFO - [('target', 0.004080894403159618), ('rrna', 0.003928156569600105), ('bacterial', 0.0033667604438960552), ('role', 0.003202405758202076), ('thus', 0.002991675166413188), ('although', 0.0028876890428364277), ('small', 0.0028868208173662424), ('determine', 0.0028026653453707695), ('respectively', 0.0027043703012168407), ('suggest', 0.002606070600450039)]
# 2024-11-15 19:45:51,359 - INFO - [('microbiota', 0.01866321824491024), ('abundance', 0.009119796566665173), ('intestinal', 0.008879810571670532), ('gut_microbiome', 0.008599980734288692), ('metabolism', 0.008287972770631313), ('level', 0.007692982908338308), ('specie_level', 0.006946571636945009), ('microbiome', 0.006701052188873291), ('mouse', 0.006216549780219793), ('microbial_diversity', 0.005624709185212851)]
# 2024-11-15 19:46:08,754 - INFO - [('manuscript_author', 0.20289260149002075), ('source_stress', 0.07750837504863739), ('available_pmc', 0.058646705001592636), ('griffith_page', 0.05306307226419449), ('economic_success', 0.026843594387173653), ('ed', 0.0244890283793211), ('socially_meaningful', 0.02041061781346798), ('allen_griffith', 0.016647567972540855), ('societal', 0.016647567972540855), ('schulz', 0.01633220724761486)]
# 2024-11-15 19:46:08,754 - INFO - [('ybmen_project', 0.13362900912761688), ('facebook_intervention', 0.08509787917137146), ('ybmen', 0.04924412816762924), ('document_copyright', 0.04313657432794571), ('association_one', 0.04313657432794571), ('allied_publisher', 0.04313657432794571), ('disseminate_broadly', 0.04313657432794571), ('black_men', 0.03923644497990608), ('pinnock', 0.028379041701555252), ('pilot', 0.02658318728208542)]
# 2024-11-15 19:46:08,755 - INFO - [('race', 0.08375538140535355), ('psychological_distress', 0.06447772681713104), ('biological_system', 0.04157743602991104), ('kirschbaum', 0.03465185686945915), ('racial', 0.031579937785863876), ('raw', 0.026347657665610313), ('martin', 0.026347657665610313), ('late_life', 0.025783220306038857), ('among_old', 0.021647371351718903), ('morbidity', 0.021082917228341103)]
# 2024-11-15 19:46:08,755 - INFO - [('church', 0.11422930657863617), ('hiv', 0.08705984055995941), ('bless_health', 0.05425615608692169), ('stis', 0.04823001101613045), ('report_supplement', 0.04823001101613045), ('session', 0.048092056065797806), ('faithbased', 0.045830853283405304), ('hiv_prevention', 0.03666885569691658), ('hivprevention_program', 0.03617772087454796), ('march_flint', 0.030151577666401863)]
# 2024-11-15 19:46:08,755 - INFO - [('author_manuscript', 0.24810342490673065), ('pmc_april', 0.11128651350736618), ('griffith_page', 0.10219726711511612), ('health_educ', 0.08957939594984055), ('behav_author', 0.08460401743650436), ('manuscript_available', 0.05792159214615822), ('pubmed', 0.03307538479566574), ('medicine_pubmed', 0.014525322243571281), ('psychology_pubmed', 0.012194378301501274), ('hr', 0.008137132972478867)]
# 2024-11-15 19:46:08,755 - INFO - [('hospice', 0.12492974102497101), ('dementia', 0.11688830703496933), ('admiral_nurse', 0.08650004863739014), ('community_practice', 0.0672852024435997), ('people_dementia', 0.0672852024435997), ('end_life', 0.04767885431647301), ('innovative', 0.02194357104599476), ('illness', 0.01829184964299202), ('referral', 0.017900345847010612), ('collaboration', 0.017064232379198074)]
# 2024-11-15 19:46:08,755 - INFO - [('transportation', 0.07532121241092682), ('interactive', 0.03768201917409897), ('interfere', 0.03295706585049629), ('healthcare', 0.03295706585049629), ('realistic', 0.03073626570403576), ('weight_loss', 0.028272220864892006), ('communitybased', 0.025808176025748253), ('type_diabetes', 0.025808176025748253), ('regular', 0.021985651925206184), ('provider', 0.020880084484815598)]
# 2024-11-15 19:46:08,756 - INFO - [('association_one', 0.09172159433364868), ('might', 0.03213724493980408), ('watkins_neighbor', 0.029974499717354774), ('smith_allen', 0.029974499717354774), ('finding_current', 0.029974499717354774), ('intention', 0.029974499717354774), ('ybmen_project', 0.029974499717354774), ('decide', 0.027574867010116577), ('park', 0.02517523430287838), ('video', 0.02517523430287838)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_930789/1187514250.py in ?()
#      11 match selected_model_name:
#      12     case "hdp":
#      13         for author_folder in all_pdf_path.iterdir():
#      14             if author_folder.is_dir():
# ---> 15                 docs = topic_model_processor.get_and_process_pdf_files(author_folder=author_folder)
#      16                 model_obj = HDPTopicModel()
#      17                 model_obj.train(docs)
#      18                 topics = model_obj.get_topics()
#
# ~/expert_field_project/data_pipeline/NLP/data_processor.py in ?(self, author_folder)
#     109     def get_and_process_pdf_files(self, author_folder):
#     110         """Convert PDFs to text, then preprocess and return lemmatized documents with bigrams."""
#     111         # Loop through each author folder in the main directory
#     112         pdf_files = [file for file in author_folder.iterdir() if file.is_file() and file.suffix == '.pdf']
# --> 113         raw_docs = self.create_docs(pdf_files)
#     114         return self.preprocess_text(raw_docs)
#
# ~/expert_field_project/data_pipeline/NLP/data_processor.py in ?(self, pdf_files)
#      91                     for page_num in range(len(pdf)):
#      92                         page = pdf.load_page(page_num)
#      93                         text += page.get_text()
#      94                     docs.append(text)
# ---> 95             except Exception as e:
#      96                 #TODO: remove problem pdfs from folder and db
#      97                 logging.warning(f"couldn't open {pdf_file}")
#      98         return docs
#
# ~/.conda/envs/test_env/lib/python3.11/site-packages/pymupdf/utils.py in ?(page, option, clip, flags, textpage, sort, delimiters, tolerance)
#     990         t = tp.extractXML()
#     991     elif option == "xhtml":
#     992         t = tp.extractXHTML()
#     993     else:
# --> 994         t = tp.extractText(sort=sort)
#     995
#     996     if textpage is None:
#     997         del tp
#
# ~/.conda/envs/test_env/lib/python3.11/site-packages/pymupdf/__init__.py in ?(self, sort)
#   12767     def extractText(self, sort=False) -> str:
#   12768         """Return simple, bare text on the page."""
#   12769         if sort is False:
# > 12770             return self._extractText(0)
#   12771         blocks = self.extractBLOCKS()[:]
#   12772         blocks.sort(key=lambda b: (b[3], b[0]))
#   12773         return "".join([b[4] for b in blocks])
#
# ~/.conda/envs/test_env/lib/python3.11/site-packages/pymupdf/__init__.py in ?(self, format_)
#   12573             mupdf.fz_print_stext_page_as_xhtml(out, this_tpage, 0)
#   12574         else:
#   12575             JM_print_stext_page_as_text(res, this_tpage)
#   12576         out.fz_close_output()
# > 12577         text = JM_EscapeStrFromBuffer(res)
#   12578         return text
#
# ~/.conda/envs/test_env/lib/python3.11/site-packages/pymupdf/__init__.py in ?(buff)
#   15206 def JM_EscapeStrFromBuffer(buff):
#   15207     if not buff.m_internal:
#   15208         return ''
#   15209     s = mupdf.fz_buffer_extract_copy(buff)
# > 15210     val = PyUnicode_DecodeRawUnicodeEscape(s, errors='replace')
#   15211     return val
#
# ~/.conda/envs/test_env/lib/python3.11/site-packages/pymupdf/__init__.py in ?(s, errors)
#   17939     if isinstance(s, str):
#   17940         rc = s.encode("utf8", errors=errors)
#   17941     elif isinstance(s, bytes):
#   17942         rc = s[:]
# > 17943     ret = rc.decode('raw_unicode_escape', errors=errors)
#   17944     return ret
#
# KeyboardInterrupt:
